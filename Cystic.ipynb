# %% [markdown]
# ## Cystic Experiment
#
# The Cystic dataset consists of 160 glycan molecules which are either associated with cystic fibrosis (positive label) or not (negative label).
#
# More information on the data set is available in the paper ["Tree Echo State Networks" by Gallicchio and Micheli (2013)](http://dx.doi.org/10.1016/j.neucom.2012.08.017).

# %%
# load the data
from tree_utils import dataset_from_json
dataset_name = 'cystic'
trees, filenames = dataset_from_json(dataset_name)

# label the data according to filename
X = []
Y = []
for i in range(len(trees)):
    if(filenames[i].startswith('-1')):
        Y.append(0)
    elif(filenames[i].startswith('1')):
        Y.append(1)
    else:
        continue
    X.append(trees[i])

del trees
del filenames

import numpy as np
Y = np.array(Y)

# %%
# compute all pairwise tree edit distances
import multiprocess as mp

D = mp.pairwise_distances_symmetric(X)

# %%
# show the distances
import matplotlib.pyplot as plt
fig, axs = plt.subplots()
cax = axs.matshow(D)
fig.colorbar(cax)
plt.show()

# %%
# set up possible C values for the SVM
Cs     = [0.1, 1., 10., 100.]

# pre-compute all kernel variations for all hyperparameter
# values
kernel_types = ['linear', 'RBF', 'ST', 'SST', 'PT']
Ks = [[], [], [], [], []]

# pre-compute linear kernel matrix via double centering
import scipy.linalg
d_row_mean = np.expand_dims(np.mean(D, axis=0), 1)
K_linear = 0.5 * (-D + d_row_mean + d_row_mean.T - np.mean(D))
Lambda, V = scipy.linalg.eig(K_linear)
Lambda[Lambda < 0] = 0
K_linear = np.real(np.dot(V, np.dot(np.diag(Lambda), V.T)))
Ks[0] = [K_linear]
del K_linear
del Lambda
del V

# pre-compute RBF kernel matrix
sigmas = np.array([0.1, 0.5, 1., 2.]) * np.mean(D)
for s in range(len(sigmas)):
    K = np.exp(-0.5 * np.square(D) / (sigmas[s] ** 2))
    K = 0.5 * (K + K.T)
    Lambda, V = scipy.linalg.eig(K)
    Lambda[Lambda < 0] = 0
    Ks[1].append(np.real(np.dot(V, np.dot(np.diag(Lambda), V.T))))
del K
del Lambda
del V

# prepare trees in PTK format
import ptk_utils
X_ptk = []
for x_nodes, x_adj in X:
    X_ptk.append(ptk_utils.to_ptk_tree(x_nodes, x_adj))
    
# pre-compute PTK kernel matrices
lambdas = [0.001, 0.01, 0.1]

for kernel_type in range(2, len(kernel_types)):
    for l in range(len(lambdas)):
        Ks[kernel_type].append(ptk_utils.pairwise_kernel_symmetric(X_ptk, kernel_types[kernel_type], lambdas[l]))

# %%
# show kernels
for kernel_type in range(2, len(kernel_types)):
    fig, axs = plt.subplots()
    cax = axs.matshow(Ks[kernel_type][-1])
    fig.colorbar(cax)
    plt.title(kernel_types[kernel_type])
    plt.show()

# %%
# set up out-of-sample methods for each kernel type
def oos_linear(x_nodes, x_adj, train_index):
    X_train = []
    for i in train_index:
        X_train.append(X[i])
    # compute the edit distances to all training data points
    d = mp.pairwise_distances([(x_nodes, x_adj)], X_train)
    # compute the kernel values
    return 0.5 * (-d + np.mean(d) + np.mean(D[:, train_index], axis=0) - np.mean(D))
    
def oos_rbf(x_nodes, x_adj, train_index, sigma):
    X_train = []
    for i in train_index:
        X_train.append(X[i])
    # compute the edit distances to all training data points
    d = mp.pairwise_distances([(x_nodes, x_adj)], X_train)
    # compute the kernel values
    return np.exp(-0.5 * np.square(d) / (sigma ** 2))
    
def oos_ptk(x_nodes, x_adj, train_index, kernel_type, lambda_):
    x = ptk_utils.to_ptk_tree(x_nodes, x_adj)
    X_train = []
    for i in train_index:
        X_train.append(ptk_utils.to_ptk_tree(X[i][0], X[i][1]))
    # compute the edit distances to all training data points
    return ptk_utils.pairwise_kernel([x], X_train, kernel_types[kernel_type], lambda_)

# %%
# gather the alphabet of out data set for recursive neural net computations
neural_net_types = ['recursive', 'tree echo state']

alphabet = set()
for i in range(len(X)):
    alphabet.update(X[i][0])
alphabet = list(alphabet)
alphabet.sort()
dim = 10
unique_labels = list(np.unique(Y))

# set up training functions for both neural net types
def recursive_train(X_train, Y_train):
    rec_net = RecursiveNetClassifier(dim, unique_labels, alphabet)
    learning_curve = rec_net.fit(X_train, Y_train, print_step = 100)
    print('completed training after %d steps' % len(learning_curve))
    return rec_net

dims = [10, 50, 100]
radii = [0.7, 0.9, 1., 1.5, 2]

def tree_echo_state_train(X_train, Y_train):
    # perform hyper-parameter optimization first
    dim, radius, _ = grid_search_cv_echo_state(X_train, Y_train, alphabet, dims, radii)
    print('finished hyper parameter optimization')
    # train tree echo state network
    rec_net = TreeEchoStateNetClassifier(dim, alphabet, radius=radius)
    rec_net.fit(X_train, Y_train)
    return rec_net

neural_net_train_funs = [recursive_train, tree_echo_state_train]

# %%
# set up crossvalidation folds
from sklearn.model_selection import StratifiedKFold
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
from recursive_net import RecursiveNetClassifier
from tree_echo_state import TreeEchoStateNetClassifier
from hyperopt import grid_search_cv_svm
from hyperopt import grid_search_cv_echo_state
from adversarial_edits import construct_random_adversarials
from adversarial_edits import construct_adversarials

n_split_outer = 10
n_split_inner = 10

outer_cv = StratifiedKFold(n_splits=n_split_outer, shuffle=True)

# set up result matrices
conditions = ['original', 'random', 'adversarial']

accs = np.zeros((n_split_outer, len(kernel_types) + len(neural_net_types), len(conditions)))
d_adversarial = np.zeros((n_split_outer, len(kernel_types) + len(neural_net_types), len(conditions) - 1))
Zs = [[[None] * len(X)] * (len(kernel_types) + len(neural_net_types))] * (len(conditions) - 1)

# iterate over the folds
f = -1
for train_index, test_index in outer_cv.split(X, Y):
    f += 1
    print('--- fold %d of %d ---' % (f+1, n_split_outer))
    X_train = []
    for i in train_index:
        X_train.append(X[i])
    X_test = []
    for i in test_index:
        X_test.append(X[i])

    # iterate over our kernels
    for kernel_type in range(len(kernel_types)):
        print('%s kernel' % kernel_types[kernel_type])
        # perform a nested crossvalidation to optimize hyper-parameters
        C, k, _ = grid_search_cv_svm(Y, Cs, Ks[kernel_type], n_split_inner, train_index)
        print('finished hyper parameter optimization')
        # select the best kernel matrix
        K = Ks[kernel_type][k]
        K_train = K[train_index, :][:, train_index]
        K_test  = K[test_index, :][:, train_index]
        # train an SVM with the optimal hyperparameters
        svm = SVC(kernel='precomputed', decision_function_shape='ovo', C = C)
        svm.fit(K_train, Y[train_index])
        # evaluate the test accuracy
        Y_pred  = svm.predict(K_test)
        correct = Y[test_index] == Y_pred
        accs[f, kernel_type, 0] = accuracy_score(Y[test_index], Y_pred)
        print('accuracy: %g' % accs[f, kernel_type, 0])
        # then, start the adversarial construction on the test data
        # set up the out of sample function for the current kernel
        if(kernel_type == 0):
            oos = oos_linear
        elif(kernel_type == 1):
            oos = lambda x_nodes, x_adj, train_index: oos_rbf(x_nodes, x_adj, train_index, sigmas[k])
        else:
            oos = lambda x_nodes, x_adj, train_index: oos_ptk(x_nodes, x_adj, train_index, kernel_type, lambdas[k])
        # set up the predictive function for the current kernel
        def predict(x_nodes, x_adj):
            # compute the kernel values of the new point to the trainign data
            k = oos(x_nodes, x_adj, train_index)
            # and then predict with the SVM
            return svm.predict(k)
        # construct random adversarials
        Z, labels, ds = construct_random_adversarials(X_test, Y[test_index], None, predict, alphabet, max_d = 100)
        # verify labels
        success = np.logical_not(np.isinf(ds))
        if(np.any(labels[success] == Y[test_index][success])):
            raise ValueError('expected changed labels in all successful cases')
        # store the proportion of attempts where adversarial construction failed
        accs[f, kernel_type, 1] = np.mean(ds[correct] >= 1.)
        print('random adversarial accuracy: %g' % accs[f, kernel_type, 1])
        # the average relative distance to an adversarial example
        d_adversarial[f, kernel_type, 0] = np.mean(ds[success])
        # and the adversarial examples themselves
        for i in range(len(test_index)):
            Zs[0][kernel_type][test_index[i]] = Z[i]
        # construct adversarials
        Z, labels, ds = construct_adversarials(X_test, D[test_index, :][:, test_index], Y[test_index], None, predict)
        # verify labels
        success = np.logical_not(np.isinf(ds))
        if(np.any(labels[success] == Y[test_index][success])):
            raise ValueError('expected changed labels in all successful cases')
        # store the proportion of attempts where adversarial construction failed
        accs[f, kernel_type, 2] = np.mean(ds[correct] >= 1.)
        print('adversarial accuracy: %g' % accs[f, kernel_type, 2])
        # the average relative distance to an adversarial example
        d_adversarial[f, kernel_type, 1] = np.mean(ds[np.logical_not(np.isinf(ds))])
        # and the adversarial examples themselves
        for i in range(len(test_index)):
            Zs[1][kernel_type][test_index[i]] = Z[i]
    # also train the neural nets on this data
    for net_type in range(len(neural_net_types)):
        t = len(kernel_types) + net_type
        print('%s network' % neural_net_types[net_type])
        rec_net = neural_net_train_funs[net_type](X_train, Y[train_index])
        # check the accuracy
        Y_pred = np.array(rec_net.predict(X_test))
        correct = Y[test_index] == Y_pred
        accs[f, t, 0] = accuracy_score(Y[test_index], Y_pred)
        print('accuracy: %g' % accs[f, t, 0])
        # set up the predictive function
        def predict(x_nodes, x_adj):
            return rec_net.predict([(x_nodes, x_adj)])[0]
        # construct random adversarials
        Z, labels, ds = construct_random_adversarials(X_test, Y[test_index], Y_pred, predict, alphabet, max_d = 100)
        # verify labels
        success = np.logical_not(np.isinf(ds))
        if(np.any(labels[success] == Y[test_index][success])):
            raise ValueError('expected changed labels in all successful cases')
        # store the proportion of attempts where adversarial construction failed
        accs[f, t, 1] = np.mean(ds[correct] >= 1.)
        print('random adversarial accuracy: %g' % accs[f, t, 1])
        # the average relative distance to an adversarial example
        d_adversarial[f, t, 0] = np.mean(ds[success])
        # and the adversarial examples themselves
        for i in range(len(test_index)):
            Zs[0][t][test_index[i]] = Z[i]
        # construct adversarials
        Z, labels, ds = construct_adversarials(X_test, D[test_index, :][:, test_index], Y[test_index], Y_pred, predict)
        # verify labels
        success = np.logical_not(np.isinf(ds))
        if(np.any(labels[success] == Y[test_index][success])):
            raise ValueError('expected changed labels in all successful cases')
        # store the proportion of attempts where adversarial construction failed
        accs[f, t, 2] = np.mean(ds[correct] >= 1.)
        print('adversarial accuracy: %g' % accs[f, t, 2])
        # the average relative distnace to an adversarial example
        d_adversarial[f, t, 1] = np.mean(ds[success])
        # and the adversarial examples themselves
        for i in range(len(test_index)):
            Zs[1][t][test_index[i]] = Z[i]
# Out:
# /usr/lib64/python3.7/site-packages/sklearn/utils/__init__.py:4: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated, and in 3.8 it will stop working
#   from collections import Sequence
# --- fold 1 of 10 ---
# linear kernel
# finished hyper parameter optimization
# accuracy: 0.529412
# random adversarial accuracy: 1
# /usr/lib64/python3.7/site-packages/numpy/core/fromnumeric.py:2920: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /usr/lib64/python3.7/site-packages/numpy/core/_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# adversarial accuracy: 0.888889
# RBF kernel
# finished hyper parameter optimization
# accuracy: 0.588235
# random adversarial accuracy: 1
# adversarial accuracy: 0.8
# ST kernel
# finished hyper parameter optimization
# accuracy: 0.647059
# random adversarial accuracy: 1
# adversarial accuracy: 0.727273
# SST kernel
# finished hyper parameter optimization
# accuracy: 0.647059
# random adversarial accuracy: 1
# adversarial accuracy: 0.818182
# PT kernel
# finished hyper parameter optimization
# accuracy: 0.647059
# random adversarial accuracy: 1
# adversarial accuracy: 0.818182
# recursive network
# lowest loss after 100 steps: 0.504489
# lowest loss after 200 steps: 0.265922
# lowest loss after 300 steps: 0.160161
# lowest loss after 400 steps: 0.0832976
# lowest loss after 500 steps: 0.0287016
# lowest loss after 600 steps: 0.0287016
# lowest loss after 700 steps: 0.0239951
# lowest loss after 800 steps: 0.0161566
# lowest loss after 900 steps: 0.0123676
# lowest loss after 1000 steps: 0.0109691
# completed training after 1019 steps
# accuracy: 0.705882
# random adversarial accuracy: 0.333333
# adversarial accuracy: 0.666667
# tree echo state network
# finished hyper parameter optimization
# accuracy: 0.647059
# random adversarial accuracy: 0.363636
# adversarial accuracy: 0.727273
# --- fold 2 of 10 ---
# linear kernel
# finished hyper parameter optimization
# accuracy: 0.875
# random adversarial accuracy: 1
# adversarial accuracy: 0.857143
# RBF kernel
# finished hyper parameter optimization
# accuracy: 0.75
# random adversarial accuracy: 1
# adversarial accuracy: 0.583333
# ST kernel
# finished hyper parameter optimization
# accuracy: 0.6875
# random adversarial accuracy: 1
# adversarial accuracy: 0.272727
# SST kernel
# finished hyper parameter optimization
# accuracy: 0.6875
# random adversarial accuracy: 1
# adversarial accuracy: 0.454545
# PT kernel
# finished hyper parameter optimization
# accuracy: 0.75
# random adversarial accuracy: 1
# adversarial accuracy: 0.5
# recursive network
# lowest loss after 100 steps: 0.609647
# lowest loss after 200 steps: 0.280082
# lowest loss after 300 steps: 0.157923
# lowest loss after 400 steps: 0.0509385
# lowest loss after 500 steps: 0.0407552
# lowest loss after 600 steps: 0.0319529
# lowest loss after 700 steps: 0.0319529
# lowest loss after 800 steps: 0.0181573
# lowest loss after 900 steps: 0.0106707
# lowest loss after 1000 steps: 0.0106707
# lowest loss after 1100 steps: 0.0106707
# completed training after 1139 steps
# accuracy: 0.75
# random adversarial accuracy: 0.75
# adversarial accuracy: 0.666667
# tree echo state network
# finished hyper parameter optimization
# accuracy: 0.6875
# random adversarial accuracy: 0.363636
# adversarial accuracy: 0.727273
# --- fold 3 of 10 ---
# linear kernel
# finished hyper parameter optimization
# accuracy: 0.75
# random adversarial accuracy: 1
# adversarial accuracy: 1
# RBF kernel
# finished hyper parameter optimization
# accuracy: 0.6875
# random adversarial accuracy: 1
# adversarial accuracy: 1
# ST kernel
# finished hyper parameter optimization
# accuracy: 0.5625
# random adversarial accuracy: 1
# adversarial accuracy: 0.222222
# SST kernel
# finished hyper parameter optimization
# accuracy: 0.625
# random adversarial accuracy: 1
# adversarial accuracy: 0.8
# PT kernel
# finished hyper parameter optimization
# accuracy: 0.625
# random adversarial accuracy: 1
# adversarial accuracy: 0.6
# recursive network
# lowest loss after 100 steps: 0.494639
# lowest loss after 200 steps: 0.428074
# lowest loss after 300 steps: 0.0944032
# lowest loss after 400 steps: 0.0929274
# lowest loss after 500 steps: 0.0665037
# lowest loss after 600 steps: 0.0276574
# lowest loss after 700 steps: 0.0276574
# lowest loss after 800 steps: 0.0276574
# lowest loss after 900 steps: 0.0211671
# lowest loss after 1000 steps: 0.0181873
# lowest loss after 1100 steps: 0.0181873
# completed training after 1160 steps
# accuracy: 0.5
# random adversarial accuracy: 0.5
# adversarial accuracy: 0.5
# tree echo state network
# finished hyper parameter optimization
# accuracy: 0.75
# random adversarial accuracy: 0.333333
# adversarial accuracy: 0.833333
# --- fold 4 of 10 ---
# linear kernel
# finished hyper parameter optimization
# accuracy: 0.75
# random adversarial accuracy: 1
# adversarial accuracy: 0.833333
# RBF kernel
# finished hyper parameter optimization
# accuracy: 0.875
# random adversarial accuracy: 1
# adversarial accuracy: 0.857143
# ST kernel
# finished hyper parameter optimization
# accuracy: 0.75
# random adversarial accuracy: 1
# adversarial accuracy: 0.666667
# SST kernel
# finished hyper parameter optimization
# accuracy: 0.6875
# random adversarial accuracy: 1
# adversarial accuracy: 0.818182
# PT kernel
# finished hyper parameter optimization
# accuracy: 0.6875
# random adversarial accuracy: 1
# adversarial accuracy: 0.909091
# recursive network
# lowest loss after 100 steps: 0.553427
# lowest loss after 200 steps: 0.406711
# lowest loss after 300 steps: 0.0719045
# lowest loss after 400 steps: 0.0719045
# lowest loss after 500 steps: 0.0256853
# lowest loss after 600 steps: 0.0256853
# lowest loss after 700 steps: 0.0256853
# lowest loss after 800 steps: 0.0215566
# lowest loss after 900 steps: 0.0215566
# lowest loss after 1000 steps: 0.0215566
# completed training after 1020 steps
# accuracy: 0.6875
# random adversarial accuracy: 0.636364
# adversarial accuracy: 0.636364
# tree echo state network
# finished hyper parameter optimization
# accuracy: 0.75
# random adversarial accuracy: 0.416667
# adversarial accuracy: 0.583333
# --- fold 5 of 10 ---
# linear kernel
# finished hyper parameter optimization
# accuracy: 0.6875
# random adversarial accuracy: 1
# adversarial accuracy: 0.909091
# RBF kernel
# finished hyper parameter optimization
# accuracy: 0.8125
# random adversarial accuracy: 1
# adversarial accuracy: 0.692308
# ST kernel
# finished hyper parameter optimization
# accuracy: 0.8125
# random adversarial accuracy: 1
# adversarial accuracy: 0.461538
# SST kernel
# finished hyper parameter optimization
# accuracy: 0.8125
# random adversarial accuracy: 1
# adversarial accuracy: 0.692308
# PT kernel
# finished hyper parameter optimization
# accuracy: 0.8125
# random adversarial accuracy: 1
# adversarial accuracy: 0.692308
# recursive network
# lowest loss after 100 steps: 0.547488
# lowest loss after 200 steps: 0.307059
# lowest loss after 300 steps: 0.121847
# lowest loss after 400 steps: 0.0912035
# lowest loss after 500 steps: 0.06723
# lowest loss after 600 steps: 0.0244521
# lowest loss after 700 steps: 0.0244521
# lowest loss after 800 steps: 0.0244521
# lowest loss after 900 steps: 0.0206093
# lowest loss after 1000 steps: 0.0156874
# lowest loss after 1100 steps: 0.0156874
# completed training after 1188 steps
# accuracy: 0.75
# random adversarial accuracy: 0.75
# adversarial accuracy: 0.833333
# tree echo state network
# finished hyper parameter optimization
# accuracy: 0.4375
# random adversarial accuracy: 0.428571
# adversarial accuracy: 0.428571
# --- fold 6 of 10 ---
# linear kernel
# finished hyper parameter optimization
# accuracy: 0.625
# random adversarial accuracy: 1
# adversarial accuracy: 0.9
# RBF kernel
# finished hyper parameter optimization
# accuracy: 0.625
# random adversarial accuracy: 1
# adversarial accuracy: 0.8
# ST kernel
# finished hyper parameter optimization
# accuracy: 0.8125
# random adversarial accuracy: 1
# adversarial accuracy: 0.846154
# SST kernel
# finished hyper parameter optimization
# accuracy: 0.75
# random adversarial accuracy: 1
# adversarial accuracy: 0.833333
# PT kernel
# finished hyper parameter optimization
# accuracy: 0.75
# random adversarial accuracy: 1
# adversarial accuracy: 0.75
# recursive network
# lowest loss after 100 steps: 0.557883
# lowest loss after 200 steps: 0.495865
# lowest loss after 300 steps: 0.242268
# lowest loss after 400 steps: 0.130574
# lowest loss after 500 steps: 0.0681742
# lowest loss after 600 steps: 0.0681742
# lowest loss after 700 steps: 0.0499636
# lowest loss after 800 steps: 0.0391323
# lowest loss after 900 steps: 0.022664
# lowest loss after 1000 steps: 0.022664
# lowest loss after 1100 steps: 0.022664
# lowest loss after 1200 steps: 0.01434
# completed training after 1227 steps
# accuracy: 0.875
# random adversarial accuracy: 0.642857
# adversarial accuracy: 0.714286
# tree echo state network
# finished hyper parameter optimization
# accuracy: 0.75
# random adversarial accuracy: 0.25
# adversarial accuracy: 0.5
# --- fold 7 of 10 ---
# linear kernel
# finished hyper parameter optimization
# accuracy: 0.6875
# random adversarial accuracy: 1
# adversarial accuracy: 0.909091
# RBF kernel
# finished hyper parameter optimization
# accuracy: 0.6875
# random adversarial accuracy: 1
# adversarial accuracy: 0.909091
# ST kernel
# finished hyper parameter optimization
# accuracy: 0.6875
# random adversarial accuracy: 1
# adversarial accuracy: 0.636364
# SST kernel
# finished hyper parameter optimization
# accuracy: 0.625
# random adversarial accuracy: 1
# adversarial accuracy: 0.7
# PT kernel
# finished hyper parameter optimization
# accuracy: 0.6875
# random adversarial accuracy: 1
# adversarial accuracy: 0.545455
# recursive network
# lowest loss after 100 steps: 0.590441
# lowest loss after 200 steps: 0.47869
# lowest loss after 300 steps: 0.155462
# lowest loss after 400 steps: 0.0796074
# lowest loss after 500 steps: 0.0671546
# lowest loss after 600 steps: 0.0337592
# lowest loss after 700 steps: 0.0337592
# lowest loss after 800 steps: 0.0217988
# lowest loss after 900 steps: 0.0217988
# lowest loss after 1000 steps: 0.0169801
# lowest loss after 1100 steps: 0.0169801
# lowest loss after 1200 steps: 0.0116752
# lowest loss after 1300 steps: 0.0116752
# lowest loss after 1400 steps: 0.0116752
# lowest loss after 1500 steps: 0.0116752
# lowest loss after 1600 steps: 0.0106601
# lowest loss after 1700 steps: 0.0106601
# completed training after 1724 steps
# accuracy: 0.8125
# random adversarial accuracy: 0.538462
# adversarial accuracy: 0.692308
# tree echo state network
# finished hyper parameter optimization
# accuracy: 0.625
# random adversarial accuracy: 0.6
# adversarial accuracy: 0.5
# --- fold 8 of 10 ---
# linear kernel
# finished hyper parameter optimization
# accuracy: 0.75
# random adversarial accuracy: 1
# adversarial accuracy: 0.75
# RBF kernel
# finished hyper parameter optimization
# accuracy: 0.75
# random adversarial accuracy: 1
# adversarial accuracy: 0.833333
# ST kernel
# finished hyper parameter optimization
# accuracy: 0.9375
# random adversarial accuracy: 1
# adversarial accuracy: 0.266667
# SST kernel
# finished hyper parameter optimization
# accuracy: 0.875
# random adversarial accuracy: 1
# adversarial accuracy: 0.5
# PT kernel
# finished hyper parameter optimization
# accuracy: 0.875
# random adversarial accuracy: 1
# adversarial accuracy: 0.5
# recursive network
# lowest loss after 100 steps: 0.632422
# lowest loss after 200 steps: 0.476197
# lowest loss after 300 steps: 0.178853
# lowest loss after 400 steps: 0.1129
# lowest loss after 500 steps: 0.076084
# lowest loss after 600 steps: 0.0539588
# lowest loss after 700 steps: 0.0539588
# lowest loss after 800 steps: 0.0539588
# lowest loss after 900 steps: 0.0224682
# lowest loss after 1000 steps: 0.0224682
# lowest loss after 1100 steps: 0.0212595
# lowest loss after 1200 steps: 0.0193132
# lowest loss after 1300 steps: 0.0193132
# lowest loss after 1400 steps: 0.0126729
# lowest loss after 1500 steps: 0.0100958
# completed training after 1549 steps
# accuracy: 0.875
# random adversarial accuracy: 0.428571
# adversarial accuracy: 0.571429
# tree echo state network
# finished hyper parameter optimization
# accuracy: 0.75
# random adversarial accuracy: 0.333333
# adversarial accuracy: 0.416667
# --- fold 9 of 10 ---
# linear kernel
# finished hyper parameter optimization
# accuracy: 0.75
# random adversarial accuracy: 1
# adversarial accuracy: 0.75
# RBF kernel
# finished hyper parameter optimization
# accuracy: 0.8125
# random adversarial accuracy: 1
# adversarial accuracy: 0.538462
# ST kernel
# finished hyper parameter optimization
# accuracy: 0.75
# random adversarial accuracy: 1
# adversarial accuracy: 0.75
# SST kernel
# finished hyper parameter optimization
# accuracy: 0.625
# random adversarial accuracy: 1
# adversarial accuracy: 0.4
# PT kernel
# finished hyper parameter optimization
# accuracy: 0.6875
# random adversarial accuracy: 1
# adversarial accuracy: 0.636364
# recursive network
# lowest loss after 100 steps: 0.65138
# lowest loss after 200 steps: 0.465685
# lowest loss after 300 steps: 0.157568
# lowest loss after 400 steps: 0.0963346
# lowest loss after 500 steps: 0.0349473
# lowest loss after 600 steps: 0.0268983
# lowest loss after 700 steps: 0.0226012
# lowest loss after 800 steps: 0.0226012
# lowest loss after 900 steps: 0.0226012
# lowest loss after 1000 steps: 0.0173886
# lowest loss after 1100 steps: 0.0163935
# lowest loss after 1200 steps: 0.0163935
# lowest loss after 1300 steps: 0.0163935
# lowest loss after 1400 steps: 0.0162189
# lowest loss after 1500 steps: 0.0162189
# lowest loss after 1600 steps: 0.0136823
# lowest loss after 1700 steps: 0.0115671
# completed training after 1712 steps
# accuracy: 0.8125
# random adversarial accuracy: 0.384615
# adversarial accuracy: 0.846154
# tree echo state network
# finished hyper parameter optimization
# accuracy: 0.8125
# random adversarial accuracy: 0.461538
# adversarial accuracy: 0.923077
# --- fold 10 of 10 ---
# linear kernel
# finished hyper parameter optimization
# accuracy: 0.8
# random adversarial accuracy: 1
# adversarial accuracy: 0.833333
# RBF kernel
# finished hyper parameter optimization
# accuracy: 0.8
# random adversarial accuracy: 1
# adversarial accuracy: 0.75
# ST kernel
# finished hyper parameter optimization
# accuracy: 0.866667
# random adversarial accuracy: 1
# adversarial accuracy: 0.230769
# SST kernel
# finished hyper parameter optimization
# accuracy: 0.866667
# random adversarial accuracy: 1
# adversarial accuracy: 0.538462
# PT kernel
# finished hyper parameter optimization
# accuracy: 0.866667
# random adversarial accuracy: 1
# adversarial accuracy: 0.538462
# recursive network
# lowest loss after 100 steps: 0.633397
# lowest loss after 200 steps: 0.493755
# lowest loss after 300 steps: 0.183915
# lowest loss after 400 steps: 0.0635489
# lowest loss after 500 steps: 0.0635489
# lowest loss after 600 steps: 0.0359963
# lowest loss after 700 steps: 0.0173405
# lowest loss after 800 steps: 0.0173405
# lowest loss after 900 steps: 0.0173405
# lowest loss after 1000 steps: 0.0141786
# lowest loss after 1100 steps: 0.0141786
# completed training after 1180 steps
# accuracy: 0.866667
# random adversarial accuracy: 0.461538
# adversarial accuracy: 0.615385
# tree echo state network
# finished hyper parameter optimization
# accuracy: 0.866667
# random adversarial accuracy: 0.153846
# adversarial accuracy: 0.769231

# %%
for kernel_type in range(len(kernel_types)):
    print('%s kernel' % kernel_types[kernel_type])
    print('on average, we needed the following distance to flip the label: %g' % np.mean(d_adversarial[:, kernel_type, -1]))
    print('we could generate adversarial examples for %g%% of the data' % (100. - 100.* np.mean(accs[:, kernel_type, -1])))
for net_type in range(len(neural_net_types)):
    t = len(kernel_types) + net_type
    print('%s network' % neural_net_types[net_type])
    print('on average, we needed the following distance to flip the label: %g' % np.mean(d_adversarial[:, t, -1]))
    print('we could generate adversarial examples for %g%% of the data' % (100. - 100.* np.mean(accs[:, t, -1])))
# Out:
# linear kernel
# on average, we needed the following distance to flip the label: 1.71217
# we could generate adversarial examples for 13.6912% of the data
# RBF kernel
# on average, we needed the following distance to flip the label: 1.68166
# we could generate adversarial examples for 22.3633% of the data
# ST kernel
# on average, we needed the following distance to flip the label: 0.85998
# we could generate adversarial examples for 49.1962% of the data
# SST kernel
# on average, we needed the following distance to flip the label: 1.25091
# we could generate adversarial examples for 34.4499% of the data
# PT kernel
# on average, we needed the following distance to flip the label: 1.25625
# we could generate adversarial examples for 35.1014% of the data
# recursive network
# on average, we needed the following distance to flip the label: 1.44688
# we could generate adversarial examples for 32.5741% of the data
# tree echo state network
# on average, we needed the following distance to flip the label: 1.23356
# we could generate adversarial examples for 35.9124% of the data

# %%
# print the results to a CSV table
np.savetxt('results/%s_accs.csv' % dataset_name, accs[:, :, 0], delimiter='\t', header='\t'.join(kernel_types + neural_net_types), fmt='%g')
np.savetxt('results/%s_accs_random_adversarial.csv' % dataset_name, accs[:, :, 1], delimiter='\t', header='\t'.join(kernel_types + neural_net_types), fmt='%g')
np.savetxt('results/%s_d_random_adversarial.csv' % dataset_name, d_adversarial[:, :, 0], delimiter='\t', header='\t'.join(kernel_types + neural_net_types), fmt='%g')
np.savetxt('results/%s_accs_adversarial.csv' % dataset_name, accs[:, :, 2], delimiter='\t', header='\t'.join(kernel_types + neural_net_types), fmt='%g')
np.savetxt('results/%s_d_adversarial.csv' % dataset_name, d_adversarial[:, :, 1], delimiter='\t', header='\t'.join(kernel_types + neural_net_types), fmt='%g')

# %%
# print the adversarial examples to a pickle file
import pickle
with open('results/%s_adversarials.pickle' % dataset_name, 'wb') as pickle_file:
    pickle.dump(Zs, pickle_file)
